# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# This is a Notebook testing and demonstrating all functions of the Stage3DSmarActMCS2 driver.
# IMPORTANT: before running this Notebook, ensure that the stage can move freely.
# First move the working directory to LabExT

address = 'usb:sn:MCS2-00018222' # VISA address MCS2 controller
#path_to_LabExT = 'C:\\Users\\jmaris\\Documents\\GitHub\\LabExT\\'

#import os
#os.chdir(path_to_LabExT)

#import LabExT.Movement.Stages.Stage3DSmarActMCS2
from LabExT.Movement.Stages.Stage3DSmarActMCS2 import Stage3DSmarActMCS2

## Initialize class

stage = Stage3DSmarActMCS2(address) # tests __init__(address)
print('The stage address is \'{}\'.'.format(stage.find_stage_addresses()))
print('The stage object is \'{}\'.'.format(stage.find_available_stages())) # function in Stage parent class
# These last two functions output [], because the test-setup only has a 6D stage. Because we know the address, we can still load it.

stage.connect()
print('Stage has been connected successfully.')
# Out:
# The stage address is '[]'.
# The stage object is '[]'.
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[2], line 23
#      20 print('The stage object is \'{}\'.'.format(stage.find_available_stages())) # function in Stage parent class
#      21 # These last two functions output [], because the test-setup only has a 6D stage. Because we know the address, we can still load it.
# ---> 23 stage.connect()
#      24 print('Stage has been connected successfully.')
#
# File c:\Users\jmaris\Documents\GitHub\LabExT\LabExT\Movement\Stage.py:50, in assert_driver_loaded.<locals>.wrapper(stage, *args, **kwargs)
#      45 if not stage.driver_loaded:
#      46     raise StageError(
#      47         "Stage driver not loaded: Function {} requires previously loaded drivers.".format(
#      48             func.__name__))
# ---> 50 return func(stage, *args, **kwargs)
#
# File c:\Users\jmaris\Documents\GitHub\LabExT\LabExT\Movement\Stages\Stage3DSmarActMCS2.py:88, in Stage3DSmarActMCS2.connect(self)
#      85     self._logger.debug('Stage is already connected.')
#      86     return True
# ---> 88 self.handle = self._open_system()
#      89 if self.handle is not None:
#      90     for ch in Axis:
#
# File c:\Users\jmaris\Documents\GitHub\LabExT\LabExT\Movement\Stages\Stage3DSmarActMCS2.py:273, in Stage3DSmarActMCS2._open_system(self)
#     272 def _open_system(self):
# --> 273     handle = ctl.Open(self.address)
#     274     if handle:
#     275         return handle
#
# File c:\Users\jmaris\.conda\envs\LabExt_p310\lib\site-packages\smaract\ctl\bindings.py:155, in Open(locator, config)
#     153 local_1 = lib.SA_CTL_Open(local_0, locator.encode(), config.encode())
#     154 if local_1 != ErrorCode.NONE.value:
# --> 155     raise Error("Open", local_1, {"locator": locator, "config": config})
#     156 return local_0[0]
#
# Error: Open returned 61466 with arguments {'locator': 'usb:sn:MCS2-00018222', 'config': ''}

# %%
## Run tests and print results
# Test all properties and functions in https://labext.readthedocs.io/en/latest/code_API_mover/ (LabExT v. 2.3.1)

# Identification
print('The adress string is \'{}\'.'.format(stage.address_string))
print('The identifier is \'{}\'.'.format(stage.identifier))
print('The string representation of the stage is \'{}\'.'.format(str(stage))) # tests __str()__
print('The statuses for the linear movers in x,y,z are {}.'.format(stage.get_status()))
# Out:
# The adress string is 'usb:sn:MCS2-00018222'.
# The identifier is 'usb:sn:MCS2-00018222'.
# The string representation of the stage is 'SmarAct Piezo-Stage at usb:sn:MCS2-00018222'.
# The statuses for the linear movers in x,y,z are (['CLOSED_LOOP_ACTIVE', 'SENSOR_PRESENT', 'IS_CALIBRATED', 'AMPLIFIER_ENABLED', 'IN_POSITION'], ['CLOSED_LOOP_ACTIVE', 'SENSOR_PRESENT', 'IS_CALIBRATED', 'AMPLIFIER_ENABLED', 'IN_POSITION'], ['CLOSED_LOOP_ACTIVE', 'SENSOR_PRESENT', 'IS_CALIBRATED', 'AMPLIFIER_ENABLED', 'IN_POSITION']).

# %%
# Get and set properties
print('The accelleration in x,y is {} um/s2. Setting to 100 um2/s.'.format(stage.get_acceleration_xy()))
stage.set_acceleration_xy(100)
assert(stage.get_acceleration_xy() == 100)
# Out:
# The accelleration in x,y is 0.0 um/s2. Setting to 100 um2/s.

# %%
print('The speed in x,y is {} um/s. Setting to 200 um/s'.format(stage.get_speed_xy()))
stage.set_speed_xy(200)
assert(stage.get_speed_xy() == 200)
# Out:
# The speed in x,y is 300.0 um/s. Setting to 200 um/s

# %%
print('The speed in z is {} um/s. Setting to 10 um/s.'.format(stage.get_speed_z()))
stage.set_speed_z(10)
assert(stage.get_speed_z() == 10)
# Out:
# The speed in z is 20.0 um/s. Setting to 10 um/s.

# %%
movement_um = (500,500,25)
print('The position of the linear movers in x,y,z are {0} um. Setting to {1}.'.format(stage.get_position(),movement_um))
stage.move_absolute(x=movement_um[0], y=movement_um[1], z=movement_um[2], wait_for_stopping=True) # stage._wait_for_stopping and stage.is_stopped are invoked
print('The position of the linear movers in x,y,z are {} um.'.format(stage.get_position()))
# Out:
# The position of the linear movers in x,y,z are [250.000983, 249.99933299999998, 9.999653] um. Setting to (500, 500, 25).
# The position of the linear movers in x,y,z are [500.00320899999997, 500.005251, 24.998642] um.

# %%
print('The position of the linear movers in x,y,z are {0} um. Moving back with {1}.'.format(stage.get_position(),movement_um))
stage.move_relative(x=-movement_um[0], y=-movement_um[1], z=-movement_um[2], wait_for_stopping=True)
# Out:
# The position of the linear movers in x,y,z are [500.00305599999996, 500.00335099999995, 25.000529] um. Moving back with (500, 500, 25).

# %%
# Close connection
stage.disconnect()
print('Stage has been disconnected successfully.')
# Out:
# Stage has been disconnected successfully.
